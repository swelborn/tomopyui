# %%
# %reload_ext autoreload
# %autoreload 2
from tomopyui.widgets.hdf_imports import HDF5_GeneralUploader
import pathlib
b = HDF5_GeneralUploader(filedir = pathlib.Path(r"C:\Users\samwe\Documents\tomopyui\data\tiff_image\8000.00eV"))
b.create_app()
b.app

# %%
import numpy as np
recon.result_after_viewer.hist.__dict__
# Out:
# {'vmin': -0.00021866515453439195,
#  'vmax': 0.002264426389126473,
#  'init_vmin': -0.0001596296060597524,
#  'init_vmax': -0.00021866515453439206,
#  'viewer': <tomopyui.widgets.view.BqImViewer_Projections_Child at 0x23b716d7e50>,
# ...

# %%
np.percentile(recon.analysis.projections.data, q=(0.5, 99.5))
# recon.result_after_viewer.hist.init_vmin
# Out:
# array([-0.00015963,  0.00194715])

# %%
np.percentile(recon.analysis.projections.data, q=(0.5, 99.5))
# Out:
# array([-0.00015963,  0.00194715])

# %%
from tomopyui.center import Center

# %%
center.add_center_button.callback = center.set_center_to_slice

# %%
import tomopyui.backend.io
import tomopyui.widgets.center
import tomopyui.widgets.view
import tomopyui.widgets.imports

# import tomopyui.backend.util.dask_downsample

# %%
align.
